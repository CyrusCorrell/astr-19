# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.random.randn(1000)

plt.hist(x,100,edgecolor='green')
plt.xlabel('Dogs')
plt.ylabel('Cats')
plt.savefig("CyrusCorrellCJ24.pdf", bbox_inches='tight',dpi=600)
